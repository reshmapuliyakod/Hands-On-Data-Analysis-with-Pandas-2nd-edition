# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('data\\parsed.csv')
data.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...  automatic
#
#             time                          title tsunami        type  \
# ...

# %%
data.describe()
# Out:
#               cdi         dmin        felt          gap          mag  \
# count  329.000000  6139.000000  329.000000  6164.000000  9331.000000
# mean     2.754711     0.544925   12.310030   121.506588     1.497345
# std      1.010637     2.214305   48.954944    72.962363     1.203347
# min      0.000000     0.000648    0.000000    12.000000    -1.260000
# 25%      2.000000     0.020425    1.000000    66.142500     0.720000
# 50%      2.700000     0.059050    2.000000   105.000000     1.300000
# 75%      3.300000     0.177250    5.000000   159.000000     1.900000
# max      8.400000    53.737000  580.000000   355.910000     7.500000
#
#              mmi          nst          rms          sig          time  \
# count  93.000000  5364.000000  9332.000000  9332.000000  9.332000e+03
# mean    3.651398    19.053878     0.362122    56.899914  1.538284e+12
# std     1.790523    15.492315     0.317784    91.872163  6.080306e+08
# ...

# %%
data.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url', 'parsed_place'],
#       dtype='object')

# %%
data[['place','parsed_place']].head()
# Out:
#                    place parsed_place
# 0  9km NE of Aguanga, CA   California
# 1  9km NE of Aguanga, CA   California
# 2  8km NE of Aguanga, CA   California
# 3  9km NE of Aguanga, CA   California
# 4  10km NW of Avenal, CA   California

# %% [markdown]
# Find the 95th percentile of earthquake magnitude in Japan using the mb magnitude type.

# %%
data[(data.parsed_place=='Japan') & ( data.magType=='mb')]['mag'].describe(percentiles=[0.95])
# Out:
# count    50.000000
# mean      4.530000
# std       0.266688
# min       4.000000
# 50%       4.600000
# 95%       4.900000
# max       5.400000
# Name: mag, dtype: float64

# %% [markdown]
# Find the percentage of earthquakes in Indonesia that were coupled with tsunamis.

# %%
data.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url', 'parsed_place'],
#       dtype='object')

# %%
indonesia_earthquakes = len(data[data.parsed_place=='Indonesia'])
Indonesia_earthquakes_tsunami = len(data[(data.parsed_place=='Indonesia') & (data.tsunami==1)])
prcnt_earthquakes_tsunami = Indonesia_earthquakes_tsunami/indonesia_earthquakes
round(prcnt_earthquakes_tsunami*100,2)
# Out:
# 23.13

# %% [markdown]
# Calculate summary statistics for earthquakes in Nevada.

# %%
data[data.parsed_place=='Nevada'].describe()
# Out:
#              cdi        dmin       felt         gap         mag   mmi  \
# count  15.000000  681.000000  15.000000  681.000000  681.000000  1.00
# mean    2.440000    0.166199   2.400000  153.668120    0.500073  2.84
# std     0.501142    0.166228   4.626013   68.735302    0.696710   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.053000   1.000000   97.380000   -0.100000  2.84
# 50%     2.200000    0.112000   1.000000  149.140000    0.400000  2.84
# 75%     2.900000    0.233000   1.000000  199.720000    0.900000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig          time  tsunami     tz  \
# count  681.000000  681.000000  681.000000  6.810000e+02    681.0  681.0
# mean    12.618209    0.151986   10.970631  1.538314e+12      0.0 -480.0
# std      9.866963    0.084662   19.607150  5.965637e+08      0.0    0.0
# ...

# %% [markdown]
# Add a column indicating whether the earthquake happened in a country or US state that is on the Ring of Fire. Use Alaska, Antarctica (look for Antarctic), Bolivia, California, Canada, Chile, Costa Rica, Ecuador, Fiji, Guatemala, Indonesia, Japan, Kermadec Islands, Mexico (be careful not to select New Mexico), New Zealand, Peru, Philippines, Russia, Taiwan, Tonga, and Washington.

# %%
ring_of_fire = ['Alaska','Antarctic','Bolivia','California', 'Canada', 'Chile', 'Costa Rica', 'Ecuador', 'Fiji', 'Guatemala', 'Indonesia', 'Japan', 'Kermadec Islands', 'Mexico', 'New Zealand', 'Peru', 'Philippines', 'Russia', 'Taiwan', 'Tonga','Washington']
data['ring_of_fire_location'] = data.parsed_place.isin(ring_of_fire)
data.ring_of_fire_location.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: ring_of_fire_location, dtype: bool

# %% [markdown]
# Calculate the number of earthquakes in the Ring of Fire locations and the number outside of them

# %%
data.ring_of_fire_location.value_counts()
# Out:
# True     7184
# False    2148
# Name: ring_of_fire_location, dtype: int64

# %% [markdown]
# Find the tsunami count along the Ring of Fire.

# %%
data[data.tsunami==1]['ring_of_fire_location'].value_counts()
# Out:
# True     45
# False    16
# Name: ring_of_fire_location, dtype: int64
